# %% [markdown]
# <h1> Exception Handling in Python </h1>

# %% [markdown]
# **Source PDF:** `12_Reading_Exception_handling.pdf`
#
# This notebook embeds the exact PDF content so you can read it inline. If you want the PDF text extracted into markdown cells instead, tell me and I'll paste the text into the notebook.

# %% [markdown]
# <iframe src="12_Reading_Exception_handling.pdf" width="100%" height="800px"></iframe>
#
# *If your Jupyter environment doesn't render the PDF, use the code cell below to display it.*

# %%
from IPython.display import IFrame
IFrame('12_Reading_Exception_handling.pdf', width=900, height=600)
